# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %%
wave_gauge_data = pd.read_csv('/lustre/geocean/WORK/users/alonsoap/personal/estancia_NUS_2026/HyCFD/outputs/molokai_cases_problem_refined/0000/wave_gauges.csv')
wave_gauge_postproces = pd.read_csv('/lustre/geocean/WORK/users/alonsoap/personal/estancia_NUS_2026/HyCFD/outputs/molokai_cases_problem_refined/0000/wave_gauges_postprocessed.csv')

# %%
(wave_gauge_data['gauge_0'] - 0.1).plot()
# Out:
# <Axes: >

# %%
wave_gauge_postproces.Hrms.plot()
# Out:
#     Unnamed: 0      Hrms        Hs       Hss  Hig  Hvlf     Setup
# 0      gauge_0  0.228264  0.110102  0.100581  0.0   0.0  0.000054
# 1      gauge_1  0.227813  0.109690  0.100200  0.0   0.0  0.000039
# 2      gauge_2  0.227946  0.109785  0.100270  0.0   0.0  0.000024
# 3      gauge_3  0.227868  0.109710  0.100182  0.0   0.0  0.000008
# 4      gauge_4  0.227717  0.109581  0.100047  0.0   0.0 -0.000008
# ..         ...       ...       ...       ...  ...   ...       ...
# 395  gauge_395  0.091554  0.023055  0.021070  0.0   0.0  0.026674
# 396  gauge_396  0.092651  0.023066  0.021070  0.0   0.0  0.026685
# 397  gauge_397  0.094728  0.022382  0.020466  0.0   0.0  0.026771
# 398  gauge_398  0.098344  0.022176  0.020268  0.0   0.0  0.026865
# 399  gauge_399  0.103354  0.022409  0.020488  0.0   0.0  0.026990
#
# [400 rows x 7 columns]
