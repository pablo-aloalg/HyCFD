# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

from utils.cfd_wrapper import OpenFoamWrapper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       3 import xarray as xr
#       5 import matplotlib.pyplot as plt
# ----> 7 from utils.cfd_wrapper import OpenFoamWrapper
#
# File /workspaces/HyCFD/utils/cfd_wrapper.py:1
# ----> 1 from bluemath_tk.wrappers.base_wrappers import BaseModelWrapper
#       3 class OpenFoamWrapper(BaseModelWrapper):
#       4     def update():
#
# ModuleNotFoundError: No module named 'bluemath_tk.wrappers.base_wrappers'

# %% [markdown]
# #### Load Data

# %%
mda_df = pd.read_csv('outputs/mda_df.csv')

# %% [markdown]
# #### 01 Inputs

# %%
cases_dir = 'outputs/openfoam_cases'
templates_dir = 'inputs/templates/openfoam'
outputs_dir = 'outputs/openfoam'
