# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

from utils.cfd_wrapper import OpenFoamWrapper

# %% [markdown]
# #### Load Data

# %%
mda_df = pd.read_csv('outputs/mda_df.csv')
mda_df = mda_df.round(2)

# %% [markdown]
# #### 01 Inputs

# %%
cases_dir = 'outputs/openfoam_cases'
templates_dir = 'inputs/templates/openfoam'
outputs_dir = 'outputs/openfoam'

# %%
metamodel_parameters = mda_df[['hs', 'tp', 'swl']].to_dict(orient="list")

fixed_parameters = {'preprocess_script':'/workspaces/HyCFD/inputs/scripts_openfoam/preprocess_case.sh'}

openfoam_wrapper = OpenFoamWrapper(
    templates_dir = templates_dir,
    metamodel_parameters = metamodel_parameters,
    fixed_parameters = {},
    output_dir = cases_dir,
)
# Out:
# 2026-02-13 04:36:52,844 - OpenFoamWrapper - WARNING - Parameter hs is not in the default_parameters
# 2026-02-13 04:36:52,845 - OpenFoamWrapper - WARNING - Parameter tp is not in the default_parameters
# 2026-02-13 04:36:52,846 - OpenFoamWrapper - WARNING - Parameter swl is not in the default_parameters

# %%
openfoam_wrapper.build_cases()
