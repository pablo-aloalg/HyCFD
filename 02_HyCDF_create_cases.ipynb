# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

from utils.cfd_wrapper import OpenFoamWrapper

# %% [markdown]
# #### Load Data

# %%
mda_df = pd.read_csv('outputs/mda_df.csv')

# %% [markdown]
# #### 01 Inputs

# %%
cases_dir = 'outputs/openfoam_cases'
templates_dir = 'inputs/templates/openfoam'
outputs_dir = 'outputs/openfoam'

# %%
mda_df.columns = ['Hs', 'Hs_L0', 'WL', 'Tp']
metamodel_parameters = mda_df[['Hs', 'Hs_L0', 'WL']].to_dict(orient="list")

openfoam_wrapper = OpenFoamWrapper(
    templates_dir = templates_dir,
    metamodel_parameters=metamodel_parameters,
    fixed_parameters={},
    output_dir=cases_dir,
)

# %%
openfoam_wrapper.build_cases()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 openfoam_wrapper.build_cases()
#
# File /workspaces/HyCFD/.venv/lib/python3.12/site-packages/bluemath_tk/wrappers/_base_wrappers.py:523, in BaseModelWrapper.build_cases(self, mode, cases_name_format, cases_to_build, num_workers)
#     519     self.logger.debug("Building cases sequentially.")
#     520     for case_context, case_dir in zip(
#     521         cases_context_to_build, cases_dir_to_build
#     522     ):
# --> 523         self.build_case_and_render_files(
#     524             case_context=case_context,
#     525             case_dir=case_dir,
#     526         )
#     528 self.logger.info(
#     529     f"{len(self.cases_dirs)} cases created in {mode} mode and saved in {self.output_dir}"
#     530 )
#     532 # Save an example sbatch file in the output directory
#
# File /workspaces/HyCFD/.venv/lib/python3.12/site-packages/bluemath_tk/wrappers/_base_wrappers.py:448, in BaseModelWrapper.build_case_and_render_files(self, case_context, case_dir)
#     446 for template_name in self.templates_name:
#     447     try:
# --> 448         self.render_file_from_template(
#     449             template_name=template_name,
#     450             context=case_context,
#     451             output_filename=op.join(case_dir, template_name),
#     452         )
#     453     except UnicodeDecodeError as _ude:
#     454         self.copy_files(
#     455             src=op.join(self.templates_dir, template_name),
#     456             dst=op.join(case_dir, template_name),
#     457         )
#
# File /workspaces/HyCFD/.venv/lib/python3.12/site-packages/bluemath_tk/wrappers/_base_wrappers.py:323, in BaseModelWrapper.render_file_from_template(self, template_name, context, output_filename)
#     321 if output_filename is None:
#     322     output_filename = op.join(self.output_dir, template_name)
# --> 323 with open(output_filename, "w") as f:
#     324     f.write(rendered_content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/openfoam_cases/0000/0/R'
