# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

from bluemath_tk.core.io import load_model

# %% [markdown]
# #### Load model and context

# %%
openfoam_wrapper = load_model('outputs/openfoam/openfoam_model.pkl')
openfoam_wrapper.load_cases()

# %% [markdown]
# #### Post-Process

# %%
output = openfoam_wrapper.postprocess_cases(cases_to_postprocess=[3])
# Out:
# Cases to postprocess was specified, so just [3] will be postprocessed.
# Remember you can just use postprocess_case method to postprocess a single case.
# Output not postprocessed for case 3. Error: This reader assumes quad faces. Face 179335 has 3 points..
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/miniforge3/envs/bluemath_tk/lib/python3.12/site-packages/xarray/structure/concat.py:254, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     253 try:
# --> 254     first_obj, objs = utils.peek_at(objs)
#     255 except StopIteration as err:
#
# File ~/miniforge3/envs/bluemath_tk/lib/python3.12/site-packages/xarray/core/utils.py:250, in peek_at(iterable)
#     249 gen = iter(iterable)
# --> 250 peek = next(gen)
#     251 return peek, itertools.chain([peek], gen)
#
# StopIteration:
#
# ...
