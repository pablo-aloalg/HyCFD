# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

from bluemath_tk.core.io import load_model

# %% [markdown]
# #### Load model and context

# %%
openfoam_wrapper = load_model('outputs/molokai_dynamic/openfoam_model.pkl')
openfoam_wrapper.load_cases()

# %% [markdown]
# #### Post-Process

# %%
output = openfoam_wrapper.postprocess_cases(cases_to_postprocess=[1,2,7])
# Out:
# Cases to postprocess was specified, so just [1, 2, 7] will be postprocessed.
# Remember you can just use postprocess_case method to postprocess a single case.
