# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

from bluemath_tk.core.io import load_model

# %% [markdown]
# #### Load model and context

# %%
openfoam_wrapper = load_model('outputs/openfoam/openfoam_model.pkl')
openfoam_wrapper.load_cases()

# %% [markdown]
# #### Post-Process

# %%
openfoam_wrapper.postprocess_cases(cases_to_postprocess=[0,1,2,3])
# Out:
# Cases to postprocess was specified, so just [0, 1, 2, 3] will be postprocessed.
# Remember you can just use postprocess_case method to postprocess a single case.
# Error joining postprocessed files: The method join_postprocessed_files must be implemented.
# [None, None, None, None]
