# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

from bluemath_tk.core.io import load_model

# %% [markdown]
# #### Load model and context

# %%
openfoam_wrapper = load_model('outputs/openfoam/open_foam_model.pkl')
openfoam_wrapper.load_cases()

# %% [markdown]
# #### Post-Process paralelization

# %%
openfoam_wrapper.postprocess_cases()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 openfoam_wrapper.postprocess_case()
#
# TypeError: OpenFoamWrapper.postprocess_case() missing 3 required positional arguments: 'case_num', 'case_dir', and 'case_context'
