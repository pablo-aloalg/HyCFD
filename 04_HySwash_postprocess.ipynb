# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

from bluemath_tk.core.io import load_model

# %% [markdown]
# #### Load model and context

# %%
swash_wrapper = load_model('outputs/hyswash_molokai_dynamic/swash_model.pkl')
swash_wrapper.load_cases()

# %% [markdown]
# #### Post-Process

# %%
post_output = swash_wrapper.postprocess_cases( write_output_nc=True)
