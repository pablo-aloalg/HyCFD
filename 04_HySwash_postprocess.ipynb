# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

from bluemath_tk.core.io import load_model

# %% [markdown]
# #### Load model and context

# %%
swash_wrapper = load_model('outputs/hyswash/swash_model.pkl')
swash_wrapper.load_cases()

# %% [markdown]
# #### Post-Process

# %%
post_output = swash_wrapper.postprocess_cases(cases_to_postprocess=[0], write_output_nc=True)
# Out:
# Cases to postprocess was specified, so just [0] will be postprocessed.
# Remember you can just use postprocess_case method to postprocess a single case.
# Output not postprocessed for case 0. Error: [Errno 2] No such file or directory: 'outputs/hyswash_cases/0000/output.tab'.
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/miniforge3/envs/openfoam/lib/python3.11/site-packages/xarray/structure/concat.py:287, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     286 try:
# --> 287     first_obj, objs = utils.peek_at(objs)
#     288 except StopIteration as err:
#
# File ~/miniforge3/envs/openfoam/lib/python3.11/site-packages/xarray/core/utils.py:287, in peek_at(iterable)
#     286 gen = iter(iterable)
# --> 287 peek = next(gen)
#     288 return peek, itertools.chain([peek], gen)
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 post_output = swash_wrapper.postprocess_cases(cases_to_postprocess=[0], write_output_nc=True)
#
# File ~/miniforge3/envs/openfoam/lib/python3.11/site-packages/bluemath_tk/wrappers/_base_wrappers.py:884, in BaseModelWrapper.postprocess_cases(self, cases_to_postprocess, write_output_nc, clean_after, **kwargs)
#     879         self.logger.error(
#     880             f"Output not postprocessed for case {case_num}. Error: {e}."
#     881         )
#     883 try:
# --> 884     output_postprocessed = self.join_postprocessed_files(
#     885         postprocessed_files=postprocessed_files
#     886     )
#     887     if write_output_nc:
#     888         self.logger.info(
#     889             f"Writing output postprocessed file to {output_postprocessed_file_path}."
#     890         )
#
# File ~/miniforge3/envs/openfoam/lib/python3.11/site-packages/bluemath_tk/wrappers/swash/swash_wrapper.py:459, in SwashModelWrapper.join_postprocessed_files(self, postprocessed_files)
#     442 def join_postprocessed_files(
#     443     self, postprocessed_files: List[xr.Dataset]
#     444 ) -> xr.Dataset:
#     445     """
#     446     Join postprocessed files in a single Dataset.
#     447
#    (...)    456         The joined Dataset.
#     457     """
# --> 459     return xr.concat(postprocessed_files, dim="case_num")
#
# File ~/miniforge3/envs/openfoam/lib/python3.11/site-packages/xarray/structure/concat.py:289, in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs, create_index_for_new_dim)
#     287     first_obj, objs = utils.peek_at(objs)
#     288 except StopIteration as err:
# --> 289     raise ValueError("must supply at least one object to concatenate") from err
#     291 if not isinstance(compat, CombineKwargDefault) and compat not in set(
#     292     _VALID_COMPAT
#     293 ) - {"minimal"}:
#     294     raise ValueError(
#     295         f"compat={compat!r} invalid: must be 'broadcast_equals', 'equals', 'identical', 'no_conflicts' or 'override'"
#     296     )
#
# ValueError: must supply at least one object to concatenate
