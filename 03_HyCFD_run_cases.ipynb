# %%
import pandas as pd
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

from bluemath_tk.core.io import load_model

# %% [markdown]
# #### Load model and context

# %%
openfoam_wrapper = load_model('outputs/openfoam/openfoam_model.pkl')
openfoam_wrapper.load_cases()

# %% [markdown]
# #### Run cases

# %%
openfoam_wrapper.run_cases(cases_to_run=[0],launcher='mpi')
# Out:
# Cases to run was specified, so just [0] will be run.
